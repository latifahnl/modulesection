# %% [markdown]
# <a href="https://colab.research.google.com/github/latifahnl/modulesection/blob/kmmodule/YOLO_v4_Custom_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TRAIN A YOLOv4 OBJECT DETECTOR**

# %% [markdown]
# #**HOW TO BEGIN**?
#
# * Click on **File** in the menu bar and click on **Save a copy in drive**.This will open a copy of my colab notebook on your browser which you can now use.
#
# * Next, once you have opened the copy of my notebook and are connected to the Google Colab VM , click on **Runtime** in the menu bar and click on **Change runtime type**. Select **GPU** and click on save.

# %% [markdown]
# # **FOLLOW THESE 12 STEPS TO TRAIN AN OBJECT DETECTOR USING YOLOv4**
#
# <ins>**NOTE**</ins>: If you get disconnected or lose your session for some reason you have to run steps 2, 5, and 6 again to mount the drive, edit makefile and build darknet every single time, otherwise the darknet executable will not work.

# %% [markdown]
# # **1) Create *`yolov4`* and *`training`* folders in your drive**
#
#  Create a folder named ***yolov4*** in your drive.
#
#  Next, create another folder named ***training*** inside the ***yolov4*** folder. This is where we will save our trained weights (This path is mentioned in the ***obj.data*** file which we will upload later)

# %% [markdown]
# # **2) Mount drive, link your folder and navigate to /mydrive/yolov4 folder**

# %%
#mount drive
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')

# this creates a symbolic link so that now the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive

# list the contents of /mydrive
# !ls /mydrive

#Navigate to /mydrive/yolov4
# %cd /mydrive/yolov4

# %% [markdown]
# # **3) Clone `darknet` git repository**

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15412, done.
# remote: Total 15412 (delta 0), reused 0 (delta 0), pack-reused 15412
# Receiving objects: 100% (15412/15412), 14.04 MiB | 6.02 MiB/s, done.
# Resolving deltas: 100% (10356/10356), done.
# Checking out files: 100% (2050/2050), done.

# %% [markdown]
# # **4) Create & upload the following files which we need for training a custom detector**
#
#
# a.   `Labeled Custom Dataset`
#
# b.   `Custom cfg file`
#
# c.   `obj.data and obj.names files`
#
# d.   `process.py file (to create train.txt and test.txt files for training)`

# %% [markdown]
# ## **4(a) Upload the Labeled custom dataset *`obj.zip`* file to the *`yolov4`* folder on your drive**
#
#
# Create the zip file **obj.zip** from the **obj** folder containing both the input image ".jpg" files and their corresponding YOLO format labeled ".txt" files.
#
# Upload the zip file to the ***yolov4*** folder on your drive.

# %% [markdown]
# ## **4(b) Create your custom *`config`* file and upload it to your drive**
#
# Download the **yolov4-custom.cfg** file from ***darknet/cfg*** directory, make changes to it, and upload it to the ***yolov4*** folder on your drive .
#
# You can also download the custom config file from the official [AlexeyAB Github](https://www.github.com/AlexeyAB/darknet)
#
#
# **You need to make the following changes in your custom config file:**
#
# *   change line batch to batch=64
# *   change line subdivisions to subdivisions=16
# *   change line max_batches to (classes*2000 but not less than number of training images and not less than 6000), f.e. max_batches=6000 if you train for 3 classes
# *    change line steps to 80% and 90% of max_batches, f.e. steps=4800,5400
# *    set network size width=416 height=416 or any value multiple of 32
# *    change line classes=80 to your number of objects in each of 3 [yolo]-layers
# *    change [filters=255] to filters=(classes + 5)x3 in the 3 [convolutional] before each [yolo] layer, keep in mind that it only has to be the last [convolutional] before each of the [yolo] layers.
#      So if classes=1 then it should be filters=18. If classes=2 then write filters=21.

# %% [markdown]
# ## **4(c) Create your *`obj.data`* and *`obj.names`* files and upload to your drive**

# %% [markdown]
# ### **obj.data**
#
# ```
# classes = 2
# train  = data/train.txt
# valid  = data/test.txt
# names = data/obj.names
# backup = /mydrive/yolov4/training
#
# ```

# %% [markdown]
# ### **obj.names**
#
# ```
# with_mask
# without_mask
# ```

# %% [markdown]
# ## **4(d) Upload the *`process.py`* script file to the *`yolov4`* folder on your drive**
#
# **To divide all image files into 2 parts. 90% for train and 10% for test.**
#
# This *`process.py`* script creates the files *`train.txt`* & *`test.txt`* where the *`train.txt`* file has paths to 90% of the images and *`test.txt`* has paths to 10% of the images.

# %% [markdown]
# # **5) Make changes in the `makefile` to enable OPENCV and GPU**

# %%
# change makefile to have GPU and OPENCV enabled
# also set CUDNN, CUDNN_HALF and LIBSO to 1

# %cd darknet/
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# !sed -i 's/LIBSO=0/LIBSO=1/' Makefile

# %% [markdown]
# # **6) Run `make` command to build darknet**

# %%
# build darknet 
# !make

# %% [markdown]
# # **7) Copy all the files from the *`yolov4`* folder to the darknet directory**

# %%
# Clean the data and cfg folders first except the labels folder in data which is required

# %cd data/
# !find -maxdepth 1 -type f -exec rm -rf {} \;
# %cd ..

# %rm -rf cfg/
# %mkdir cfg

# %%
# Unzip the obj.zip dataset and its contents so that they are now in /darknet/data/ folder 

# !unzip /mydrive/yolov4/obj.zip -d data/

# %%
# Copy the yolov4-custom.cfg file so that it is now in /darknet/cfg/ folder 

# !cp /mydrive/yolov4/yolov4-custom.cfg cfg

# verify if your custom file is in cfg folder
# !ls cfg/

# %%
# Copy the obj.names and obj.data files from your drive so that they are now in /darknet/data/ folder 

# !cp /mydrive/yolov4/obj.names data
# !cp /mydrive/yolov4/obj.data  data

# verify if the above files are in data folder
# !ls data/

# %%
# Copy the process.py file to the current darknet directory 

# !cp /mydrive/yolov4/process.py .

# %% [markdown]
# # **8) Run the *`process.py`* python script to create the *`train.txt`* & *`test.txt`* files inside the *data* folder**

# %%
# run process.py ( this creates the train.txt and test.txt files in our darknet/data folder )
# !python process.py

# list the contents of data folder to check if the train.txt and test.txt files have been created 
# !ls data/

# %% [markdown]
# # **9) Download the pre-trained *`yolov4`* weights**

# %%
# Download the yolov4 pre-trained weights file
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %% [markdown]
# # **10) TRAINING**

# %% [markdown]
# ## **Train your custom detector**
#
# For best results, you should stop the training when the average loss is less than 0.05 if possible or at least below 0.3, else train the model until the average loss does not show any significant change for a while.

# %%
# train your custom detector! (uncomment %%capture below if you run into memory issues or your Colab is crashing)
# %%capture

# !./darknet detector train data/obj.data cfg/yolov4-custom.cfg yolov4.conv.137 -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.432997), count: 4, class_loss = 4590.176270, iou_loss = 3.528809, total_loss = 4593.705078
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.336464), count: 12, class_loss = 1128.585205, iou_loss = 0.794922, total_loss = 1129.380127
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.434003), count: 16, class_loss = 354.567230, iou_loss = 0.259094, total_loss = 354.826324
#  total_bbox = 5908, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.395543), count: 16, class_loss = 4540.257324, iou_loss = 18.818359, total_loss = 4559.075684
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.375882), count: 21, class_loss = 1123.781494, iou_loss = 2.655518, total_loss = 1126.437012
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.357417), count: 26, class_loss = 351.486389, iou_loss = 0.412933, total_loss = 351.899323
#  total_bbox = 5971, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.452635), count: 5, class_loss = 4548.981445, iou_loss = 5.501465, total_loss = 4554.482910
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.408946), count: 24, class_loss = 1129.397217, iou_loss = 2.455322, total_loss = 1131.852539
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.439573), count: 34, class_loss = 353.563629, iou_loss = 0.766327, total_loss = 354.329956
#  total_bbox = 6034, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  10: 2012.621216, 2014.192261 avg loss, 0.000000 rate, 13.182692 seconds, 640 images, 21.532808 hours left
# Resizing, random_coef = 1.40
#
#  480 x 480
#  try to allocate additional workspace_size = 132.71 MB
#  CUDA allocate done!
# Loaded: 1.523833 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.162800), count: 3, class_loss = 2824.609131, iou_loss = 0.208496, total_loss = 2824.817627
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.319559), count: 19, class_loss = 699.137451, iou_loss = 0.780334, total_loss = 699.917786
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.359202), count: 23, class_loss = 223.135315, iou_loss = 0.246689, total_loss = 223.382004
#  total_bbox = 6079, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.266362), count: 1, class_loss = 2825.708496, iou_loss = 0.152588, total_loss = 2825.861084
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.380661), count: 23, class_loss = 700.834778, iou_loss = 1.296875, total_loss = 702.131653
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.375367), count: 29, class_loss = 222.438217, iou_loss = 0.557602, total_loss = 222.995819
#  total_bbox = 6132, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.197667), count: 2, class_loss = 2829.459717, iou_loss = 0.147217, total_loss = 2829.606934
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.343090), count: 20, class_loss = 701.654602, iou_loss = 0.877380, total_loss = 702.531982
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.395624), count: 31, class_loss = 223.059341, iou_loss = 0.602066, total_loss = 223.661407
#  total_bbox = 6185, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2843.227051, iou_loss = 0.000000, total_loss = 2843.227051
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.373042), count: 1, class_loss = 702.398682, iou_loss = 0.037842, total_loss = 702.436523
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.555963), count: 11, class_loss = 224.881622, iou_loss = 0.152145, total_loss = 225.033768
#  total_bbox = 6197, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.340089), count: 14, class_loss = 2839.636719, iou_loss = 4.578857, total_loss = 2844.215576
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.359991), count: 26, class_loss = 705.119812, iou_loss = 2.925842, total_loss = 708.045654
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.398353), count: 8, class_loss = 224.294189, iou_loss = 0.123886, total_loss = 224.418076
#  total_bbox = 6245, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.239782), count: 1, class_loss = 2829.566406, iou_loss = 0.060791, total_loss = 2829.627197
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.355123), count: 16, class_loss = 701.029663, iou_loss = 1.404053, total_loss = 702.433716
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.386354), count: 10, class_loss = 219.313095, iou_loss = 0.088974, total_loss = 219.402069
#  total_bbox = 6272, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2837.140137, iou_loss = 0.000000, total_loss = 2837.140137
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.370567), count: 2, class_loss = 700.637939, iou_loss = 0.054749, total_loss = 700.692688
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.446093), count: 10, class_loss = 223.819656, iou_loss = 0.155518, total_loss = 223.975174
#  total_bbox = 6284, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.447344), count: 8, class_loss = 2841.087891, iou_loss = 4.831543, total_loss = 2845.919434
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.373290), count: 16, class_loss = 705.072510, iou_loss = 1.768860, total_loss = 706.841370
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.404793), count: 10, class_loss = 225.221695, iou_loss = 0.194885, total_loss = 225.416580
#  total_bbox = 6318, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.419672), count: 10, class_loss = 2827.335449, iou_loss = 4.362305, total_loss = 2831.697754
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.334718), count: 23, class_loss = 702.502625, iou_loss = 1.634583, total_loss = 704.137207
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.346137), count: 19, class_loss = 222.004333, iou_loss = 0.261795, total_loss = 222.266129
#  total_bbox = 6370, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.291592), count: 3, class_loss = 2833.104736, iou_loss = 0.696045, total_loss = 2833.800781
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.339451), count: 19, class_loss = 700.244507, iou_loss = 0.699402, total_loss = 700.943909
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.396020), count: 32, class_loss = 222.568192, iou_loss = 0.409882, total_loss = 222.978073
#  total_bbox = 6424, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.342547), count: 34, class_loss = 2831.224365, iou_loss = 24.515381, total_loss = 2855.739746
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.344450), count: 51, class_loss = 706.092407, iou_loss = 3.914490, total_loss = 710.006897
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.388283), count: 26, class_loss = 220.444855, iou_loss = 0.442459, total_loss = 220.887314
#  total_bbox = 6535, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.285756), count: 13, class_loss = 2824.737305, iou_loss = 2.786865, total_loss = 2827.524170
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.381195), count: 38, class_loss = 703.473083, iou_loss = 3.381775, total_loss = 706.854858
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.374382), count: 33, class_loss = 222.005096, iou_loss = 0.489288, total_loss = 222.494385
#  total_bbox = 6619, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2820.533936, iou_loss = 0.000000, total_loss = 2820.533936
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.394689), count: 23, class_loss = 703.977539, iou_loss = 1.076965, total_loss = 705.054504
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.355830), count: 30, class_loss = 220.167557, iou_loss = 0.392151, total_loss = 220.559708
#  total_bbox = 6672, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.264146), count: 10, class_loss = 2834.219238, iou_loss = 7.115479, total_loss = 2841.334717
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.331367), count: 13, class_loss = 703.355225, iou_loss = 0.564026, total_loss = 703.919250
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.387269), count: 16, class_loss = 223.497421, iou_loss = 0.200897, total_loss = 223.698318
#  total_bbox = 6711, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.324470), count: 8, class_loss = 2835.594238, iou_loss = 3.090820, total_loss = 2838.685059
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.348810), count: 12, class_loss = 703.043579, iou_loss = 0.947632, total_loss = 703.991211
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.381613), count: 9, class_loss = 221.805252, iou_loss = 0.064163, total_loss = 221.869415
#  total_bbox = 6740, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.075090), count: 1, class_loss = 2827.242188, iou_loss = 0.006836, total_loss = 2827.249023
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.334723), count: 10, class_loss = 699.669006, iou_loss = 0.407959, total_loss = 700.076965
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.399776), count: 11, class_loss = 223.512878, iou_loss = 0.095901, total_loss = 223.608780
#  total_bbox = 6762, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  11: 1252.194824, 1937.992554 avg loss, 0.000000 rate, 8.971714 seconds, 704 images, 21.536827 hours left
# Loaded: 0.000059 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.212906), count: 2, class_loss = 2830.961426, iou_loss = 0.254883, total_loss = 2831.216309
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.315517), count: 28, class_loss = 705.289429, iou_loss = 1.120361, total_loss = 706.409790
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.402354), count: 25, class_loss = 223.400772, iou_loss = 0.411758, total_loss = 223.812531
#  total_bbox = 6817, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.167394), count: 2, class_loss = 2816.385254, iou_loss = 0.056152, total_loss = 2816.441406
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.506381), count: 16, class_loss = 700.908997, iou_loss = 1.349609, total_loss = 702.258606
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.392645), count: 28, class_loss = 223.325363, iou_loss = 0.421539, total_loss = 223.746902
#  total_bbox = 6863, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.336581), count: 4, class_loss = 2826.081787, iou_loss = 0.947754, total_loss = 2827.029541
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.384578), count: 24, class_loss = 704.308594, iou_loss = 1.302490, total_loss = 705.611084
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.390150), count: 24, class_loss = 221.888458, iou_loss = 0.392136, total_loss = 222.280594
#  total_bbox = 6915, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.497712), count: 2, class_loss = 2841.744385, iou_loss = 1.158447, total_loss = 2842.902832
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.371233), count: 30, class_loss = 705.926453, iou_loss = 1.601379, total_loss = 707.527832
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.395169), count: 28, class_loss = 221.646713, iou_loss = 0.572891, total_loss = 222.219604
#  total_bbox = 6975, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.396515), count: 5, class_loss = 2826.592285, iou_loss = 4.881104, total_loss = 2831.473389
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.331758), count: 13, class_loss = 700.485779, iou_loss = 0.509644, total_loss = 700.995422
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.350615), count: 26, class_loss = 220.536224, iou_loss = 0.247208, total_loss = 220.783432
#  total_bbox = 7019, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.216626), count: 1, class_loss = 2831.286865, iou_loss = 0.058594, total_loss = 2831.345459
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.598089), count: 3, class_loss = 698.339355, iou_loss = 0.282715, total_loss = 698.622070
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.381639), count: 14, class_loss = 221.369812, iou_loss = 0.100906, total_loss = 221.470718
#  total_bbox = 7037, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2827.204834, iou_loss = 0.000000, total_loss = 2827.204834
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.418409), count: 3, class_loss = 702.060669, iou_loss = 0.270935, total_loss = 702.331604
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.400461), count: 9, class_loss = 223.711441, iou_loss = 0.087158, total_loss = 223.798599
#  total_bbox = 7049, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2840.471436, iou_loss = 0.000000, total_loss = 2840.471436
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.370571), count: 2, class_loss = 701.649536, iou_loss = 0.060730, total_loss = 701.710266
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.495464), count: 10, class_loss = 222.365738, iou_loss = 0.135406, total_loss = 222.501144
#  total_bbox = 7061, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.358731), count: 2, class_loss = 2824.863525, iou_loss = 0.500732, total_loss = 2825.364258
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.408026), count: 18, class_loss = 703.564270, iou_loss = 0.950745, total_loss = 704.515015
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.370926), count: 29, class_loss = 225.072815, iou_loss = 0.461395, total_loss = 225.534210
#  total_bbox = 7110, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.450222), count: 4, class_loss = 2826.024902, iou_loss = 3.551514, total_loss = 2829.576416
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.430258), count: 17, class_loss = 697.918457, iou_loss = 1.786377, total_loss = 699.704834
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.382464), count: 23, class_loss = 219.837372, iou_loss = 0.269226, total_loss = 220.106598
#  total_bbox = 7154, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.323718), count: 5, class_loss = 2828.075439, iou_loss = 1.581055, total_loss = 2829.656494
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.422895), count: 21, class_loss = 702.330994, iou_loss = 1.442261, total_loss = 703.773254
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.404467), count: 25, class_loss = 221.591904, iou_loss = 0.370773, total_loss = 221.962677
#  total_bbox = 7205, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.421331), count: 14, class_loss = 2814.602783, iou_loss = 6.120361, total_loss = 2820.723145
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.377753), count: 48, class_loss = 703.590393, iou_loss = 4.316711, total_loss = 707.907104
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.373450), count: 32, class_loss = 217.966537, iou_loss = 0.478439, total_loss = 218.444977
#  total_bbox = 7299, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.298324), count: 10, class_loss = 2828.597656, iou_loss = 3.945068, total_loss = 2832.542725
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.336156), count: 17, class_loss = 700.737793, iou_loss = 1.879639, total_loss = 702.617432
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.400735), count: 17, class_loss = 221.772781, iou_loss = 0.162277, total_loss = 221.935059
#  total_bbox = 7343, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.262118), count: 3, class_loss = 2834.191162, iou_loss = 0.819336, total_loss = 2835.010498
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.319416), count: 21, class_loss = 704.832092, iou_loss = 1.038818, total_loss = 705.870911
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.319217), count: 24, class_loss = 219.626816, iou_loss = 0.301437, total_loss = 219.928253
#  total_bbox = 7391, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.306038), count: 10, class_loss = 2842.403564, iou_loss = 2.014648, total_loss = 2844.418213
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.347569), count: 30, class_loss = 707.898682, iou_loss = 2.933411, total_loss = 710.832092
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.375553), count: 26, class_loss = 220.552078, iou_loss = 0.400269, total_loss = 220.952347
#  total_bbox = 7456, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.183244), count: 1, class_loss = 2823.262451, iou_loss = 0.065918, total_loss = 2823.328369
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.415019), count: 23, class_loss = 701.245605, iou_loss = 1.440063, total_loss = 702.685669
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.392012), count: 29, class_loss = 221.973328, iou_loss = 0.497528, total_loss = 222.470856
#  total_bbox = 7509, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  12: 1251.062256, 1869.299561 avg loss, 0.000000 rate, 8.783599 seconds, 768 images, 21.496065 hours left
# Loaded: 0.000075 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2829.801270, iou_loss = 0.000000, total_loss = 2829.801270
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.331113), count: 10, class_loss = 702.098999, iou_loss = 0.486633, total_loss = 702.585632
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.459607), count: 8, class_loss = 223.543839, iou_loss = 0.176193, total_loss = 223.720032
#  total_bbox = 7527, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2838.381104, iou_loss = 0.000000, total_loss = 2838.381104
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.397241), count: 10, class_loss = 701.798584, iou_loss = 0.700134, total_loss = 702.498718
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.515509), count: 14, class_loss = 224.050659, iou_loss = 0.359406, total_loss = 224.410065
#  total_bbox = 7551, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2827.614258, iou_loss = 0.000000, total_loss = 2827.614258
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.584922), count: 3, class_loss = 700.640381, iou_loss = 0.203186, total_loss = 700.843567
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.353297), count: 9, class_loss = 222.049103, iou_loss = 0.075226, total_loss = 222.124329
#  total_bbox = 7563, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2841.656006, iou_loss = 0.000000, total_loss = 2841.656006
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 699.242065, iou_loss = 0.000000, total_loss = 699.242065
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.373275), count: 11, class_loss = 223.180756, iou_loss = 0.072754, total_loss = 223.253510
#  total_bbox = 7574, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2834.716309, iou_loss = 0.000000, total_loss = 2834.716309
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.325799), count: 14, class_loss = 702.820679, iou_loss = 0.647095, total_loss = 703.467773
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.425430), count: 14, class_loss = 224.422989, iou_loss = 0.402557, total_loss = 224.825546
#  total_bbox = 7602, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2827.636230, iou_loss = 0.000000, total_loss = 2827.636230
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 698.350159, iou_loss = 0.000000, total_loss = 698.350159
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.496275), count: 9, class_loss = 220.538284, iou_loss = 0.062241, total_loss = 220.600525
#  total_bbox = 7611, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2833.511719, iou_loss = 0.000000, total_loss = 2833.511719
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.379574), count: 1, class_loss = 699.663696, iou_loss = 0.026123, total_loss = 699.689819
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.529717), count: 8, class_loss = 222.318451, iou_loss = 0.104126, total_loss = 222.422577
#  total_bbox = 7620, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.346350), count: 10, class_loss = 2844.019531, iou_loss = 6.352295, total_loss = 2850.371826
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.333384), count: 3, class_loss = 704.790466, iou_loss = 0.304260, total_loss = 705.094727
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.446857), count: 6, class_loss = 225.034271, iou_loss = 0.056610, total_loss = 225.090881
#  total_bbox = 7639, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.350681), count: 16, class_loss = 2812.660645, iou_loss = 5.851318, total_loss = 2818.511963
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.342061), count: 48, class_loss = 709.092346, iou_loss = 3.461426, total_loss = 712.553772
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.352269), count: 32, class_loss = 222.125580, iou_loss = 0.476898, total_loss = 222.602478
#  total_bbox = 7735, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.450013), count: 24, class_loss = 2816.821289, iou_loss = 18.397217, total_loss = 2835.218506
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.429598), count: 39, class_loss = 705.918335, iou_loss = 4.815796, total_loss = 710.734131
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.429193), count: 24, class_loss = 223.591263, iou_loss = 0.490036, total_loss = 224.081299
#  total_bbox = 7822, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.383617), count: 5, class_loss = 2842.783691, iou_loss = 1.655762, total_loss = 2844.439453
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.375096), count: 15, class_loss = 699.984314, iou_loss = 1.449402, total_loss = 701.433716
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.436724), count: 14, class_loss = 219.428833, iou_loss = 0.245285, total_loss = 219.674118
#  total_bbox = 7856, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.352860), count: 13, class_loss = 2835.075928, iou_loss = 14.124268, total_loss = 2849.200195
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.356953), count: 14, class_loss = 703.216980, iou_loss = 0.936890, total_loss = 704.153870
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.373549), count: 13, class_loss = 226.648148, iou_loss = 0.198059, total_loss = 226.846207
#  total_bbox = 7896, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2835.233887, iou_loss = 0.000000, total_loss = 2835.233887
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.369878), count: 9, class_loss = 701.936279, iou_loss = 0.375671, total_loss = 702.311951
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.364602), count: 16, class_loss = 224.973541, iou_loss = 0.137390, total_loss = 225.110931
#  total_bbox = 7921, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2829.988525, iou_loss = 0.000000, total_loss = 2829.988525
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 700.710266, iou_loss = 0.000000, total_loss = 700.710266
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.475964), count: 10, class_loss = 220.741959, iou_loss = 0.086609, total_loss = 220.828568
#  total_bbox = 7931, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.409339), count: 9, class_loss = 2832.679199, iou_loss = 3.625488, total_loss = 2836.304688
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.368001), count: 15, class_loss = 704.621521, iou_loss = 1.778320, total_loss = 706.399841
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.386946), count: 10, class_loss = 223.085007, iou_loss = 0.142578, total_loss = 223.227585
#  total_bbox = 7965, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2831.013428, iou_loss = 0.000000, total_loss = 2831.013428
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.209033), count: 2, class_loss = 700.962524, iou_loss = 0.029175, total_loss = 700.991699
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.420752), count: 9, class_loss = 222.362671, iou_loss = 0.062149, total_loss = 222.424820
#  total_bbox = 7976, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  13: 1252.456421, 1807.615234 avg loss, 0.000000 rate, 8.781921 seconds, 832 images, 21.427206 hours left
# Loaded: 0.000097 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.099368), count: 3, class_loss = 2820.542969, iou_loss = 0.057373, total_loss = 2820.600342
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.323663), count: 25, class_loss = 702.202820, iou_loss = 1.146423, total_loss = 703.349243
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.407027), count: 26, class_loss = 222.690155, iou_loss = 0.458786, total_loss = 223.148941
#  total_bbox = 8030, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.252961), count: 2, class_loss = 2837.308594, iou_loss = 0.260498, total_loss = 2837.569092
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.375060), count: 19, class_loss = 703.525635, iou_loss = 1.303894, total_loss = 704.829529
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.358497), count: 27, class_loss = 222.963379, iou_loss = 0.277832, total_loss = 223.241211
#  total_bbox = 8078, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.389104), count: 3, class_loss = 2827.900146, iou_loss = 1.714600, total_loss = 2829.614746
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.291421), count: 14, class_loss = 701.695312, iou_loss = 0.563293, total_loss = 702.258606
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.383380), count: 22, class_loss = 220.569016, iou_loss = 0.445908, total_loss = 221.014923
#  total_bbox = 8117, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.090639), count: 3, class_loss = 2830.219727, iou_loss = 0.033691, total_loss = 2830.253418
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.369711), count: 13, class_loss = 702.303894, iou_loss = 1.006409, total_loss = 703.310303
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.349656), count: 17, class_loss = 219.754272, iou_loss = 0.141678, total_loss = 219.895950
#  total_bbox = 8150, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.300627), count: 17, class_loss = 2820.431152, iou_loss = 6.317871, total_loss = 2826.749023
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.359426), count: 59, class_loss = 705.111816, iou_loss = 4.246582, total_loss = 709.358398
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.361940), count: 35, class_loss = 223.513763, iou_loss = 0.664047, total_loss = 224.177811
#  total_bbox = 8261, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.185742), count: 2, class_loss = 2830.759277, iou_loss = 0.118164, total_loss = 2830.877441
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.379650), count: 20, class_loss = 700.546875, iou_loss = 1.268433, total_loss = 701.815308
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.352314), count: 26, class_loss = 223.246964, iou_loss = 0.298645, total_loss = 223.545609
#  total_bbox = 8309, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.260791), count: 11, class_loss = 2831.043701, iou_loss = 1.910889, total_loss = 2832.954590
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.368495), count: 38, class_loss = 706.191345, iou_loss = 2.909546, total_loss = 709.100891
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.319085), count: 29, class_loss = 223.347717, iou_loss = 0.338028, total_loss = 223.685745
#  total_bbox = 8387, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.247734), count: 2, class_loss = 2802.975586, iou_loss = 0.275879, total_loss = 2803.251465
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.371500), count: 23, class_loss = 697.072571, iou_loss = 1.249573, total_loss = 698.322144
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.429535), count: 23, class_loss = 218.350296, iou_loss = 0.369904, total_loss = 218.720200
#  total_bbox = 8435, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.074059), count: 2, class_loss = 2818.431152, iou_loss = 0.020996, total_loss = 2818.452148
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.356634), count: 21, class_loss = 702.198730, iou_loss = 1.033264, total_loss = 703.231995
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.398975), count: 31, class_loss = 223.559464, iou_loss = 0.428421, total_loss = 223.987885
#  total_bbox = 8489, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.329242), count: 6, class_loss = 2826.631348, iou_loss = 1.788330, total_loss = 2828.419678
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.363891), count: 28, class_loss = 703.719727, iou_loss = 1.490540, total_loss = 705.210266
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.394844), count: 30, class_loss = 221.554550, iou_loss = 0.470383, total_loss = 222.024933
#  total_bbox = 8553, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.221901), count: 4, class_loss = 2835.596924, iou_loss = 0.218994, total_loss = 2835.815918
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.390455), count: 25, class_loss = 703.015869, iou_loss = 1.400452, total_loss = 704.416321
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.366267), count: 20, class_loss = 223.396881, iou_loss = 0.282242, total_loss = 223.679123
#  total_bbox = 8602, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.287924), count: 2, class_loss = 2837.399902, iou_loss = 0.283203, total_loss = 2837.683105
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.388924), count: 11, class_loss = 704.059021, iou_loss = 0.537476, total_loss = 704.596497
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.400735), count: 19, class_loss = 224.083694, iou_loss = 0.230270, total_loss = 224.313965
#  total_bbox = 8634, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2833.813477, iou_loss = 0.000000, total_loss = 2833.813477
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.686391), count: 1, class_loss = 701.977173, iou_loss = 0.052551, total_loss = 702.029724
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.499029), count: 8, class_loss = 224.343903, iou_loss = 0.063660, total_loss = 224.407562
#  total_bbox = 8643, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.391475), count: 12, class_loss = 2816.698486, iou_loss = 6.479248, total_loss = 2823.177734
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.378082), count: 18, class_loss = 702.505188, iou_loss = 3.022827, total_loss = 705.528015
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.465701), count: 15, class_loss = 224.612778, iou_loss = 0.217651, total_loss = 224.830429
#  total_bbox = 8688, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.463019), count: 14, class_loss = 2828.791260, iou_loss = 10.612549, total_loss = 2839.403809
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.352013), count: 33, class_loss = 703.772339, iou_loss = 2.918518, total_loss = 706.690857
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.400842), count: 28, class_loss = 222.158508, iou_loss = 0.359375, total_loss = 222.517883
#  total_bbox = 8763, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2819.819336, iou_loss = 0.000000, total_loss = 2819.819336
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.289385), count: 18, class_loss = 700.990906, iou_loss = 0.509216, total_loss = 701.500122
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.445921), count: 25, class_loss = 218.073395, iou_loss = 0.414246, total_loss = 218.487640
#  total_bbox = 8806, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  14: 1250.333252, 1751.887085 avg loss, 0.000000 rate, 8.763223 seconds, 896 images, 21.358984 hours left
# Loaded: 0.000052 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.415667), count: 3, class_loss = 2830.829102, iou_loss = 3.976074, total_loss = 2834.805176
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.363566), count: 25, class_loss = 702.168396, iou_loss = 1.341553, total_loss = 703.509949
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.423310), count: 27, class_loss = 222.694885, iou_loss = 0.518738, total_loss = 223.213623
#  total_bbox = 8861, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.145290), count: 2, class_loss = 2833.902832, iou_loss = 0.068848, total_loss = 2833.971680
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.424620), count: 21, class_loss = 703.313354, iou_loss = 1.309875, total_loss = 704.623230
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.398423), count: 29, class_loss = 220.457794, iou_loss = 0.464157, total_loss = 220.921951
#  total_bbox = 8913, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2825.189453, iou_loss = 0.000000, total_loss = 2825.189453
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.374788), count: 18, class_loss = 702.415710, iou_loss = 0.743896, total_loss = 703.159607
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.409650), count: 33, class_loss = 223.788254, iou_loss = 0.499863, total_loss = 224.288116
#  total_bbox = 8964, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.354852), count: 6, class_loss = 2822.270020, iou_loss = 2.408447, total_loss = 2824.678467
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.405762), count: 29, class_loss = 704.307678, iou_loss = 2.637756, total_loss = 706.945435
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.354693), count: 24, class_loss = 222.021301, iou_loss = 0.288635, total_loss = 222.309937
#  total_bbox = 9023, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.075639), count: 3, class_loss = 2833.614014, iou_loss = 0.035400, total_loss = 2833.649414
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.367822), count: 22, class_loss = 699.924927, iou_loss = 0.992920, total_loss = 700.917847
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.405463), count: 28, class_loss = 222.349014, iou_loss = 0.378433, total_loss = 222.727448
#  total_bbox = 9076, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.136702), count: 4, class_loss = 2827.439697, iou_loss = 0.172607, total_loss = 2827.612305
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.360464), count: 27, class_loss = 702.189026, iou_loss = 1.981995, total_loss = 704.171021
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.386633), count: 26, class_loss = 223.242203, iou_loss = 0.446396, total_loss = 223.688599
#  total_bbox = 9133, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.306005), count: 14, class_loss = 2833.621582, iou_loss = 4.266357, total_loss = 2837.887939
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.346119), count: 41, class_loss = 704.357605, iou_loss = 3.142639, total_loss = 707.500244
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.378253), count: 19, class_loss = 221.256119, iou_loss = 0.422226, total_loss = 221.678345
#  total_bbox = 9207, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.349371), count: 39, class_loss = 2817.073486, iou_loss = 20.885986, total_loss = 2837.959473
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.341896), count: 51, class_loss = 703.853699, iou_loss = 4.525330, total_loss = 708.379028
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.365723), count: 26, class_loss = 223.781281, iou_loss = 0.280975, total_loss = 224.062256
#  total_bbox = 9323, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2830.891113, iou_loss = 0.000000, total_loss = 2830.891113
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.370742), count: 20, class_loss = 698.657410, iou_loss = 0.824341, total_loss = 699.481750
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.411637), count: 28, class_loss = 221.763199, iou_loss = 0.419479, total_loss = 222.182678
#  total_bbox = 9371, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.333323), count: 5, class_loss = 2822.781494, iou_loss = 1.576660, total_loss = 2824.358154
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.376580), count: 28, class_loss = 702.776978, iou_loss = 1.671326, total_loss = 704.448303
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.410785), count: 30, class_loss = 218.548050, iou_loss = 0.477844, total_loss = 219.025894
#  total_bbox = 9434, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.242175), count: 2, class_loss = 2828.812012, iou_loss = 0.182617, total_loss = 2828.994629
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.401794), count: 24, class_loss = 707.059570, iou_loss = 1.546997, total_loss = 708.606567
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.421292), count: 29, class_loss = 220.427811, iou_loss = 0.597351, total_loss = 221.025162
#  total_bbox = 9489, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2826.144531, iou_loss = 0.000000, total_loss = 2826.144531
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 701.784851, iou_loss = 0.000000, total_loss = 701.784851
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.469662), count: 10, class_loss = 222.260071, iou_loss = 0.092102, total_loss = 222.352173
#  total_bbox = 9499, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.212551), count: 5, class_loss = 2832.102295, iou_loss = 0.525635, total_loss = 2832.627930
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.417340), count: 10, class_loss = 705.329346, iou_loss = 2.012756, total_loss = 707.342102
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.434859), count: 12, class_loss = 224.321991, iou_loss = 0.212326, total_loss = 224.534317
#  total_bbox = 9526, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.392525), count: 30, class_loss = 2841.338135, iou_loss = 14.474854, total_loss = 2855.812988
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.293700), count: 32, class_loss = 707.143616, iou_loss = 2.152405, total_loss = 709.296021
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.474663), count: 10, class_loss = 223.662857, iou_loss = 0.152100, total_loss = 223.814957
#  total_bbox = 9598, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2828.917480, iou_loss = 0.000000, total_loss = 2828.917480
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 700.281128, iou_loss = 0.000000, total_loss = 700.281128
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.422273), count: 10, class_loss = 223.108307, iou_loss = 0.078842, total_loss = 223.187149
# ...
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.426971), count: 27, class_loss = 276.063477, iou_loss = 0.415070, total_loss = 276.478546
#  total_bbox = 51813, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.339500), count: 11, class_loss = 2329.906006, iou_loss = 4.329590, total_loss = 2334.235596
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.371033), count: 45, class_loss = 768.236450, iou_loss = 4.574951, total_loss = 772.811401
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.377877), count: 44, class_loss = 277.732239, iou_loss = 0.889404, total_loss = 278.621643
#  total_bbox = 51913, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.296470), count: 8, class_loss = 2323.744385, iou_loss = 3.273438, total_loss = 2327.017822
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.412476), count: 17, class_loss = 767.306396, iou_loss = 1.863220, total_loss = 769.169617
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.393143), count: 27, class_loss = 274.846191, iou_loss = 0.545471, total_loss = 275.391663
#  total_bbox = 51965, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.593625), count: 1, class_loss = 2308.833984, iou_loss = 1.090088, total_loss = 2309.924072
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.331716), count: 4, class_loss = 749.907532, iou_loss = 0.168945, total_loss = 750.076477
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.408832), count: 7, class_loss = 275.791199, iou_loss = 0.068848, total_loss = 275.860046
#  total_bbox = 51977, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2306.832520, iou_loss = 0.000000, total_loss = 2306.832520
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.475531), count: 9, class_loss = 751.243347, iou_loss = 0.905518, total_loss = 752.148865
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.421542), count: 13, class_loss = 276.271484, iou_loss = 0.281189, total_loss = 276.552673
#  total_bbox = 51999, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.358770), count: 2, class_loss = 2316.620117, iou_loss = 0.700684, total_loss = 2317.320801
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.459151), count: 7, class_loss = 757.177612, iou_loss = 0.831482, total_loss = 758.009094
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.416258), count: 18, class_loss = 275.818054, iou_loss = 0.248352, total_loss = 276.066406
#  total_bbox = 52026, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.280069), count: 7, class_loss = 2334.052002, iou_loss = 1.781250, total_loss = 2335.833252
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.351521), count: 29, class_loss = 766.815063, iou_loss = 3.002808, total_loss = 769.817871
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.417331), count: 27, class_loss = 274.658691, iou_loss = 0.664215, total_loss = 275.322906
#  total_bbox = 52089, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.393429), count: 6, class_loss = 2318.813965, iou_loss = 3.983398, total_loss = 2322.797363
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.386439), count: 30, class_loss = 766.045776, iou_loss = 3.009155, total_loss = 769.054932
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.325374), count: 34, class_loss = 277.547211, iou_loss = 0.659302, total_loss = 278.206512
#  total_bbox = 52159, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2337.298584, iou_loss = 0.000000, total_loss = 2337.298584
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.404813), count: 13, class_loss = 756.938721, iou_loss = 1.375916, total_loss = 758.314636
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.454314), count: 17, class_loss = 276.197174, iou_loss = 0.557587, total_loss = 276.754761
#  total_bbox = 52189, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2327.544678, iou_loss = 0.000000, total_loss = 2327.544678
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.566720), count: 3, class_loss = 758.822571, iou_loss = 0.360962, total_loss = 759.183533
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.540931), count: 10, class_loss = 275.179565, iou_loss = 0.210388, total_loss = 275.389954
#  total_bbox = 52202, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.225853), count: 7, class_loss = 2326.437500, iou_loss = 1.744385, total_loss = 2328.181885
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.398444), count: 17, class_loss = 759.333862, iou_loss = 2.587769, total_loss = 761.921631
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.407612), count: 9, class_loss = 274.862610, iou_loss = 0.297150, total_loss = 275.159760
#  total_bbox = 52235, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2302.484619, iou_loss = 0.000000, total_loss = 2302.484619
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 749.624023, iou_loss = 0.000000, total_loss = 749.624023
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.408855), count: 9, class_loss = 277.121429, iou_loss = 0.055969, total_loss = 277.177399
#  total_bbox = 52244, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2305.161377, iou_loss = 0.000000, total_loss = 2305.161377
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.350254), count: 6, class_loss = 750.052612, iou_loss = 0.378601, total_loss = 750.431213
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.388701), count: 9, class_loss = 275.978485, iou_loss = 0.126312, total_loss = 276.104797
#  total_bbox = 52259, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.366512), count: 23, class_loss = 2316.687256, iou_loss = 19.394531, total_loss = 2336.081787
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.404078), count: 28, class_loss = 758.957275, iou_loss = 4.415710, total_loss = 763.372986
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.415639), count: 21, class_loss = 275.474518, iou_loss = 0.563354, total_loss = 276.037872
#  total_bbox = 52331, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.293180), count: 3, class_loss = 2309.322754, iou_loss = 0.852295, total_loss = 2310.175049
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.408339), count: 21, class_loss = 762.722717, iou_loss = 2.775635, total_loss = 765.498352
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.374157), count: 30, class_loss = 276.241241, iou_loss = 0.614136, total_loss = 276.855377
#  total_bbox = 52385, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.278397), count: 14, class_loss = 2328.457764, iou_loss = 4.629639, total_loss = 2333.087402
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.402364), count: 45, class_loss = 767.163696, iou_loss = 6.008362, total_loss = 773.172058
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.395457), count: 33, class_loss = 276.037415, iou_loss = 0.896912, total_loss = 276.934326
#  total_bbox = 52477, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  82: 1118.554321, 965.189697 avg loss, 0.000000 rate, 12.069041 seconds, 5248 images, 17.562853 hours left
# Loaded: 0.000067 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.276437), count: 2, class_loss = 2240.616699, iou_loss = 0.272949, total_loss = 2240.889648
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.378233), count: 23, class_loss = 750.271179, iou_loss = 2.646423, total_loss = 752.917603
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.395945), count: 32, class_loss = 274.051056, iou_loss = 0.614044, total_loss = 274.665100
#  total_bbox = 52534, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.292770), count: 8, class_loss = 2249.925293, iou_loss = 5.451172, total_loss = 2255.376465
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.348394), count: 24, class_loss = 755.670105, iou_loss = 2.105774, total_loss = 757.775879
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.426167), count: 35, class_loss = 274.629120, iou_loss = 0.793610, total_loss = 275.422729
#  total_bbox = 52601, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.067795), count: 1, class_loss = 2234.810059, iou_loss = 0.006836, total_loss = 2234.816895
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.388569), count: 33, class_loss = 750.005005, iou_loss = 2.850220, total_loss = 752.855225
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.361924), count: 35, class_loss = 275.307159, iou_loss = 0.832825, total_loss = 276.139984
#  total_bbox = 52670, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.358968), count: 4, class_loss = 2253.114258, iou_loss = 1.766113, total_loss = 2254.880371
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.347847), count: 23, class_loss = 751.017517, iou_loss = 1.841187, total_loss = 752.858704
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.377665), count: 35, class_loss = 275.295441, iou_loss = 0.583252, total_loss = 275.878693
#  total_bbox = 52732, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.355523), count: 20, class_loss = 2253.554932, iou_loss = 12.060059, total_loss = 2265.614990
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.372562), count: 49, class_loss = 758.493774, iou_loss = 6.553833, total_loss = 765.047607
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.355277), count: 35, class_loss = 273.843018, iou_loss = 0.685577, total_loss = 274.528595
#  total_bbox = 52836, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.262582), count: 4, class_loss = 2232.884521, iou_loss = 1.176758, total_loss = 2234.061279
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.404552), count: 25, class_loss = 753.844482, iou_loss = 2.384644, total_loss = 756.229126
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.365945), count: 33, class_loss = 273.194763, iou_loss = 0.608276, total_loss = 273.803040
#  total_bbox = 52898, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.442516), count: 5, class_loss = 2245.471191, iou_loss = 3.678467, total_loss = 2249.149658
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.363670), count: 36, class_loss = 749.313843, iou_loss = 3.624634, total_loss = 752.938477
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.352780), count: 29, class_loss = 274.515411, iou_loss = 0.592010, total_loss = 275.107422
#  total_bbox = 52968, rewritten_bbox = 0.001888 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.358760), count: 9, class_loss = 2235.844971, iou_loss = 5.588135, total_loss = 2241.433105
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.368596), count: 33, class_loss = 754.238342, iou_loss = 3.696716, total_loss = 757.935059
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.339899), count: 25, class_loss = 271.013885, iou_loss = 0.398499, total_loss = 271.412384
#  total_bbox = 53035, rewritten_bbox = 0.001886 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2256.214600, iou_loss = 0.000000, total_loss = 2256.214600
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 741.209351, iou_loss = 0.000000, total_loss = 741.209351
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.700082), count: 7, class_loss = 271.298065, iou_loss = 0.110779, total_loss = 271.408844
#  total_bbox = 53042, rewritten_bbox = 0.001885 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2240.902344, iou_loss = 0.000000, total_loss = 2240.902344
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 745.667542, iou_loss = 0.000000, total_loss = 745.667542
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.535867), count: 7, class_loss = 269.975494, iou_loss = 0.062378, total_loss = 270.037872
#  total_bbox = 53049, rewritten_bbox = 0.001885 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 2211.923340, iou_loss = 0.000000, total_loss = 2211.923340
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.403997), count: 5, class_loss = 739.792297, iou_loss = 0.369873, total_loss = 740.162170
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.441108), count: 15, class_loss = 272.908661, iou_loss = 0.385162, total_loss = 273.293823
#  total_bbox = 53069, rewritten_bbox = 0.001884 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.397262), count: 5, class_loss = 2242.601074, iou_loss = 3.708740, total_loss = 2246.309814
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.314028), count: 17, class_loss = 752.035828, iou_loss = 1.404175, total_loss = 753.440002
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.416352), count: 28, class_loss = 271.869965, iou_loss = 0.518524, total_loss = 272.388489
#  total_bbox = 53119, rewritten_bbox = 0.001883 %

# %%
# This stops 'Run all' at this cell by causing an error
assert False

# %% [markdown]
# ### **<ins>NOTE</ins>:** If you get disconnected or lose your session for some reason you have to run steps 2, 5, and 6 again to mount the drive, edit makefile and build darknet every single time, otherwise the darknet executable will not work.

# %% [markdown]
# ## **To restart your training (In case the training does not finish and you get disconnected)**
#
# If you get disconnected or lose your session, you don't have to start training your model from scratch again. You can restart training from where you left off. Use the weights that were saved last. The weights are saved every 100 iterations as ***yolov4-custom_last.weights*** in the ***yolov4/training*** folder on your drive. (The path we gave as backup in "obj.data" file).
#
#
# ### **So to restart training run only Steps 2, 5, 6 and then run the following command**

# %%
#to restart training your custom detector where you left off(using the weights that were saved last)

# !./darknet detector train data/obj.data cfg/yolov4-custom.cfg /mydrive/yolov4/training/yolov4-custom_last.weights -dont_show -map

# %% [markdown]
# # **11) Check performance**

# %%
# define helper function imShow
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %% [markdown]
# **Check the training chart**

# %%
#only works if the training does not get interrupted
imShow('chart.png')

# %% [markdown]
# **Check mAP (mean average precision)**

# %%
##You can check the mAP for all the saved weights to see which gives the best results ( xxxx here is the saved weight number like 4000, 5000 or 6000 snd so on )

# !./darknet detector map data/obj.data cfg/yolov4-custom.cfg /mydrive/yolov4/training/yolov4-custom_4000.weights -points 0

# %% [markdown]
# # **12) Test your custom Object Detector**

# %% [markdown]
# ## **Make changes to your custom config file**
# *   change line batch to batch=1
# *   change line subdivisions to subdivisions=1
#
# You can do it either manually or by simply running the code below

# %%
#set your custom cfg to test mode 
# %cd cfg
# !sed -i 's/batch=64/batch=1/' yolov4-custom.cfg
# !sed -i 's/subdivisions=16/subdivisions=1/' yolov4-custom.cfg
# %cd ..

# %% [markdown]
# ## **Run detector on an image**

# %%
# run your custom detector with this command (upload an image to your google drive to test, the thresh flag sets the minimum accuracy required for object detection)

# !./darknet detector test data/obj.data cfg/yolov4-custom.cfg /mydrive/yolov4/training/yolov4-custom_best.weights /mydrive/mask_test_images/image1.jpg -thresh 0.3 
imShow('predictions.jpg')

# %% [markdown]
# ## **Run detector on a webcam image**

# %%
#run detector on images captured by webcam for your custom YOLOv4 trained model
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# !./darknet detector test data/obj.data cfg/yolov4-custom.cfg /mydrive/yolov4/training/yolov4-custom_best.weights photo.jpg -thresh 0.5
imShow('predictions.jpg')

# %% [markdown]
# ## **Run detector on a video**

# %%
# run your custom detector on a video with this command (upload a video to your google drive to test, the thresh flag sets the minimum accuracy required for object detection).This saves the output video with the detections in your output path

# !./darknet detector demo data/obj.data cfg/yolov4-custom.cfg /mydrive/yolov4/training/yolov4-custom_best.weights -dont_show /mydrive/mask_test_videos/test3.mp4 -i 0 -out_filename /mydrive/mask_test_videos/finalresult.avi

# %% [markdown]
# ## **Run detector on a live webcam**

# %%
# Code from theAIGuysCode Github (https://github.com/theAIGuysCode/YOLOv4-Cloud-Tutorial/blob/master/yolov4_webcam.ipynb)
# Adjusted for my custom YOLOv4 trained weights, config and obj.data files

# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from google.colab.patches import cv2_imshow
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time
import matplotlib.pyplot as plt
# %matplotlib inline


# import darknet functions to perform object detections
from darknet import *
# load in our YOLOv4 architecture network
network, class_names, class_colors = load_network("cfg/yolov4-custom.cfg", "data/obj.data", "/mydrive/yolov4/training/yolov4-custom_best.weights")
width = network_width(network)
height = network_height(network)

# darknet helper function to run detection on image
def darknet_helper(img, width, height):
  darknet_image = make_image(width, height, 3)
  img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  img_resized = cv2.resize(img_rgb, (width, height),
                              interpolation=cv2.INTER_LINEAR)

  # get image ratios to convert bounding boxes to proper size
  img_height, img_width, _ = img.shape
  width_ratio = img_width/width
  height_ratio = img_height/height

  # run model on darknet style image to get detections
  copy_image_from_bytes(darknet_image, img_resized.tobytes())
  detections = detect_image(network, class_names, darknet_image)
  free_image(darknet_image)
  return detections, width_ratio, height_ratio

# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes  

# JavaScript to properly create our live video stream using our webcam as input
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# start streaming video from webcam
video_stream()
# label for video
label_html = 'Capturing...'
# initialze bounding box to empty
bbox = ''
count = 0 
while True:
    js_reply = video_frame(label_html, bbox)
    if not js_reply:
        break

    # convert JS response to OpenCV Image
    frame = js_to_image(js_reply["img"])

    # create transparent overlay for bounding box
    bbox_array = np.zeros([480,640,4], dtype=np.uint8)

    # call our darknet helper on video frame
    detections, width_ratio, height_ratio = darknet_helper(frame, width, height)

    # loop through detections and draw them on transparent overlay image
    for label, confidence, bbox in detections:
      left, top, right, bottom = bbox2points(bbox)
      left, top, right, bottom = int(left * width_ratio), int(top * height_ratio), int(right * width_ratio), int(bottom * height_ratio)
      bbox_array = cv2.rectangle(bbox_array, (left, top), (right, bottom), class_colors[label], 2)
      bbox_array = cv2.putText(bbox_array, "{} [{:.2f}]".format(label, float(confidence)),
                        (left, top - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                        class_colors[label], 2)

    bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
    # convert overlay of bbox into bytes
    bbox_bytes = bbox_to_bytes(bbox_array)
    # update bbox so next frame gets new overlay
    bbox = bbox_bytes
